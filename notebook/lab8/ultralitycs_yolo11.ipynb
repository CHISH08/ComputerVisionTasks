# %%
# !pip install ultralytics

# %% [markdown]
# ## Загружаем предобученные веса модели yolov11n

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

# %%
# Обучаем модель
results = model.train(
    data='/kaggle/input/diordataset/Diorkaggle.yaml',
    epochs=8,
    imgsz=640,
    batch=32,
    lr0=3e-3,
    name="yolov11_dior",
    freeze=22, # замораживаем 22 слоя из 29
    save_period=4,
    val=True,

    # Параметры аугментации:
    hsv_h=0.015,   # Изменение оттенка (hue)
    hsv_s=0.7,     # Изменение насыщенности (saturation)
    hsv_v=0.4,     # Изменение яркости (value)
    flipud=0.0,    # Отключение вертикального отражения
    fliplr=0.5,    # Горизонтальное отражение с вероятностью 50%
    mosaic=1.0,    # Включение мозаики (объединение 4 изображений)
    degrees=0.0,   # Поворот изображений (в градусах)
    translate=0.1, # Сдвиг изображений на 10%
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.110 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
import os

# %%
image_dir = "/kaggle/input/diordataset/Dior/Dior/images/val"
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir)[:5]]

# Предсказание с сохранением результатов
results = model.predict(
    source=image_files,  # Список изображений [[4]]
    save=True,           # Сохранить изображения с боксами [[3]]
    save_dir="output",   # Папка для сохранения [[5]]
    conf=0.4            # Порог уверенности
)
# Out:
# 0: 640x640 8 vehicles, 10.1ms
# 1: 640x640 2 basketballcourts, 10.1ms
# 2: 640x640 (no detections), 10.1ms
# 3: 640x640 1 basketballcourt, 10.1ms
# 4: 640x640 4 baseballfields, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/yolov11_dior113

# %%
# !zip -r output.zip .
# Out:
#   adding: yolov8n.pt (deflated 9%)
#   adding: yolo11n.pt (deflated 11%)
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/yolov11_dior112/ (stored 0%)
#   adding: runs/detect/yolov11_dior112/12512.jpg (deflated 4%)
#   adding: runs/detect/yolov11_dior112/12278.jpg (deflated 4%)
#   adding: runs/detect/yolov11_dior112/12007.jpg (deflated 0%)
#   adding: runs/detect/yolov11_dior112/12575.jpg (deflated 0%)
#   adding: runs/detect/yolov11_dior112/12204.jpg (deflated 0%)
#   adding: runs/detect/yolov11_dior112/12778.jpg (deflated 3%)
#   adding: runs/detect/yolov11_dior112/12060.jpg (deflated 0%)
#   adding: runs/detect/yolov11_dior112/11801.jpg (deflated 0%)
#   adding: runs/detect/yolov11_dior112/12855.jpg (deflated 0%)
#   adding: runs/detect/yolov11_dior112/12313.jpg (deflated 2%)
#   adding: runs/detect/yolov11_dior112/12209.jpg (deflated 0%)
#   adding: runs/detect/yolov11_dior112/12843.jpg (deflated 0%)
# ...
